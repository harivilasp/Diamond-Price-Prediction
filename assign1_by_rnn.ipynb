# %%
# Importing the libraries
import numpy as np
import sys
np.set_printoptions(suppress=True)
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('diamonds.csv')
dataset.values
X = dataset.iloc[:,1:11].values
X = np.delete(X, 6, 1)  # delete second column of C
y = dataset.iloc[:, 6].values

# %%
dataset
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8               9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9              10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %%
#np.set_printoptions(threshold=sys.maxsize)
X
# Out:
# array([[0.23, 'Ideal', 'E', ..., 3.95, 3.98, 2.43],
#        [0.21, 'Premium', 'E', ..., 3.89, 3.84, 2.31],
#        [0.23, 'Good', 'E', ..., 4.05, 4.07, 2.31],
#        ...,
#        [0.7, 'Very Good', 'D', ..., 5.66, 5.68, 3.56],
#        [0.86, 'Premium', 'H', ..., 6.15, 6.12, 3.74],
#        [0.75, 'Ideal', 'D', ..., 5.83, 5.87, 3.64]], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
label_cut = LabelEncoder()
label_color = LabelEncoder()
label_clarity = LabelEncoder()


X[:,1] = label_cut.fit_transform(X[:,1])
X[:,2] = label_color.fit_transform(X[:,2])
X[:,3] = label_clarity.fit_transform(X[:,3])

X
# Out:
# array([[0.23, 2, 1, ..., 3.95, 3.98, 2.43],
#        [0.21, 3, 1, ..., 3.89, 3.84, 2.31],
#        [0.23, 1, 1, ..., 4.05, 4.07, 2.31],
#        ...,
#        [0.7, 4, 0, ..., 5.66, 5.68, 3.56],
#        [0.86, 3, 4, ..., 6.15, 6.12, 3.74],
#        [0.75, 2, 0, ..., 5.83, 5.87, 3.64]], dtype=object)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
X_train=sc.fit_transform(X_train)
y_train=np.reshape(y_train,(len(y_train),1))
y_train = sc.fit_transform(y_train)

# %%
len(X_train)
# Out:
# 43152

# %%
X_train=np.reshape(X_train, (len(X_train),9,1))

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
import warnings
warnings.filterwarnings('ignore')
regressor =Sequential()
regressor.add(LSTM(units=4, activation='sigmoid',input_shape=(None,1)))

# %%
regressor.add(Dense(units=1))

# %%
# recommended optimizer for RNN is rms , may use adam
# errroe MEAN SQUARE ERROR
regressor.compile(optimizer='adam',loss='mean_squared_error')

# %%
regressor.fit(X_train,y_train,batch_size=32,epochs=7)
# Out:
# Epoch 1/7
# 43152/43152 [==============================] - 5s 127us/step - loss: 0.0490
# Epoch 2/7
# 43152/43152 [==============================] - 5s 122us/step - loss: 0.0038 0s - loss: 0
# Epoch 3/7
# 43152/43152 [==============================] - 5s 122us/step - loss: 0.0038
# Epoch 4/7
# 43152/43152 [==============================] - 5s 116us/step - loss: 0.0037
# Epoch 5/7
# 43152/43152 [==============================] - 5s 124us/step - loss: 0.0037
# Epoch 6/7
# 43152/43152 [==============================] - 5s 124us/step - loss: 0.0037
# Epoch 7/7
# 43152/43152 [==============================] - 5s 125us/step - loss: 0.0036

# %%
X_test=sc.fit_transform(X_test)
X_test=np.reshape(X_test, (len(X_test),9,1))
y_test=np.reshape(y_test,(len(y_test),1))
y_test = sc.fit_transform(y_test)

# %%
predicted_price=regressor.predict(X_test)
len(predicted_price[0])
# Out:
# 1

# %%
plt.plot(y_test,color='red',label='real diamond price')
plt.plot(predicted_price,color='blue',label='predicted diamond price')
plt.title('Diamond Price Prediction')
plt.xlabel('Parameters')
plt.ylabel('Diamond Price')
plt.legend()
plt.show()
